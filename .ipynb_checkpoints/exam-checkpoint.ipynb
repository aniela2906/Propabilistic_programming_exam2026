# %% [markdown]
# <div style="
#     border:1px solid #ccc;
#     padding:25px;
#     border-radius:12px;
#     text-align:center;
#     margin:40px auto;
#     max-width:700px;
# ">
#
# <h1 style="margin-bottom:5px;">Probabilistic Programming</h1>
# <h3 style="color:gray; margin-top:0;">Spring 2026</h3>
#
# <hr style="width:60%; margin:20px auto;">
#
# <p style="text-align:center;"><strong>Exam</strong></p>
#
# <p style="text-align:center;"><b>Course code:</b> BSPRPRO1KU</p>
#
# <p style="text-align:center; margin-top:15px;">
# <a href="mailto:anci@itu.dk">anci@itu.dk</a><br>
# <a href="mailto:jaga@itu.dk">jaga@itu.dk</a><br>
# <a href="mailto:zobr@itu.dk">zobr@itu.dk</a>
# </p>
#
# <hr style="width:60%; margin:25px auto;">
#
# <h3 style="margin-top:10px;">
# An analysis of the propensity of Large Language Models to generate programs with software vulnerabilities
# </h3>
#
# </div>

# %% [markdown]
# Loading the dataset:

# %%
import pandas as pd

df = pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#   c_file_name    category                            error_type    llm_name  \
# 0      6109.c  VULNERABLE     dereference failure: NULL pointer      llama2
# 1     24107.c  VULNERABLE     dereference failure: NULL pointer  gemini_pro
# 2     74967.c  VULNERABLE            arithmetic overflow on sub       gpt35
# 3     15468.c  VULNERABLE    array bounds violated: upper bound      llama2
# 4     12779.c  VULNERABLE  dereference failure: invalid pointer      falcon
#
#    num_parameters  num_lines  cyclomatic_complexity
# 0            13.0         63                  2.333
# 1             NaN         55                  1.667
# 2             NaN        107                  6.000
# 3            13.0         56                  9.000
# 4           180.0         74                  6.000

# %%
list(df.columns)
# Out:
# ['c_file_name',
#  'category',
#  'error_type',
#  'llm_name',
#  'num_parameters',
#  'num_lines',
#  'cyclomatic_complexity']

# %%
df.dtypes
# Out:
# c_file_name               object
# category                  object
# error_type                object
# llm_name                  object
# num_parameters           float64
# num_lines                  int64
# cyclomatic_complexity    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1766 entries, 0 to 1765
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   c_file_name            1766 non-null   object
#  1   category               1766 non-null   object
#  2   error_type             1513 non-null   object
#  3   llm_name               1766 non-null   object
#  4   num_parameters         839 non-null    float64
#  5   num_lines              1766 non-null   int64
#  6   cyclomatic_complexity  1766 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 96.7+ KB

# %%
df.shape
# Out:
# (1766, 7)

# %%
summary = pd.DataFrame({
    "column": df.columns,
    "dtype": df.dtypes.values,
    "missing_values": df.isna().sum().values,
    "unique_values": df.nunique().values
})

summary
# Out:
#                   column    dtype  missing_values  unique_values
# 0            c_file_name   object               0           1728
# 1               category   object               0              4
# 2             error_type   object             253             29
# 3               llm_name   object               0              9
# 4         num_parameters  float64             927              4
# 5              num_lines    int64               0            170
# 6  cyclomatic_complexity  float64               0            175
